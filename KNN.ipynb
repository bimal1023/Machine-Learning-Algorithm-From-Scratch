# %% [markdown]
# # KNN from Scratch

# %% [markdown]
# ## K-Nearest Neighbors(KNN) is a supervised machine learning algorithm.
# It predicts the label of a new data point by:
# - measuring its distance from all training points
# - finding the K closest points
# - taking the majority class among those neighbors
# so KNN is basically :
# " Look at the nearest examples, and predict based on them."

# %% [markdown]
# ## Small dataset
# let's make a tiny dataset

# %%
import numpy as np
X_train=np.array([
    [1,2],
    [2,3],
    [3,3],
    [6,5],
    [7,7],
    [8,6]
])
y_train=np.array([0,0,0,1,1,1])

# %% [markdown]
# Here, X_train=features
#
# y_train=labels

# %%
from collections import Counter
class KNN:
    def __init__(self, k=3):
        self.k = k

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y

    def euclidean_distance(self, x1, x2):
        return np.sqrt(np.sum((x1 - x2) ** 2))

    def predict_one(self, x):
        distances = []

        # compute distance from x to all training samples
        for x_train in self.X_train:
            dist = self.euclidean_distance(x, x_train)
            distances.append(dist)

        # get indices of k nearest neighbors
        k_indices = np.argsort(distances)[:self.k]

        # get labels of k nearest neighbors
        k_nearest_labels = [self.y_train[i] for i in k_indices]

        # majority vote
        most_common = Counter(k_nearest_labels).most_common(1)
        return most_common[0][0]

    def predict(self, X):
        predictions = [self.predict_one(x) for x in X]
        return np.array(predictions)

# %%
# test data
X_test = np.array([
    [2, 2],
    [5, 5],
    [7, 6]
])

# %%
knn = KNN(k=3)
knn.fit(X_train, y_train)

predictions = knn.predict(X_test)
print("Predictions:", predictions)
# Out:
# Predictions: [0 1 1]

# %% [markdown]
# ## Adding Accuracy function

# %%
def accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / len(y_true)

# %%
y_true = np.array([0, 0, 1])
y_pred = predictions

print("Accuracy:", accuracy(y_true, y_pred))
# Out:
# Accuracy: 0.6666666666666666
